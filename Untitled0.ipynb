# %% [markdown]
# <a href="https://colab.research.google.com/github/ARshaik0/VAC_py/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('wow')
# Out:
# wow
